# %% [markdown]
# # 프로그래머스

# %% [markdown]
# ## [Lv. 1](https://school.programmers.co.kr/learn/challenges?order=recent&levels=1&languages=python3&page=1)

# %% [markdown]
# ### [[1차] 다트 게임](https://school.programmers.co.kr/learn/courses/30/lessons/17682)

# %%
#실패
def solution(dartResult):
    dR = dartResult
    dRarr = []
    answer = 0
    
    #계산루프만 돌리도록 게임을 숫자배열화(dRarr)
    for i, dr in enumerate(dR):
        if i+2 < len(dR) and dr.isdigit() and not(dR[i+1].isdigit()):
            arr = []
            arr.append(int(dr))
            if dR[i+1] == "S":
                arr.append(1)
            elif dR[i+1] == "D":
                arr.append(2)
            elif dR[i+1] == "T":
                arr.append(3)
            if dR[i+2] == "*":
                arr.append(2)
            elif dR[i+2] == "#":
                arr.append(-1)
            dRarr.append(arr)
        if i+3 < len(dR) and dr.isdigit() and dR[i+1].isdigit():
            arr = []
            arr.append(int(dR[i:i+2]))
            if dR[i+2] == "S":
                arr.append(1)
            elif dR[i+2] == "D":
                arr.append(2)
            elif dR[i+2] == "T":
                arr.append(3)
            if dR[i+3] == "*":
                arr.append(2)
            elif dR[i+3] == "#":
                arr.append(-1)
            dRarr.append(arr)
    
    #만든 숫자배열(dRarr)로 계산하기
    for round in dRarr:
        ans = round[0]
        for i in range(round[1]):
            ans *= ans
        round[2]
        if len(round) == 3:
            ans *= round[2]
        answer += ans
    return answer

# %% [markdown]
# - for i in range(n):
# - for i, chr in enumerate(str):
# - chr.isdigit()
# - int(n)
# - 조건 따질 때 ==
# - 배열에 요소 추가 arr.append(str)
# - if, elif, else
# - len()
# - False and dR[i+1].isdigit() → 오른쪽 절대 실행 안 함
#
#     not(dR[i+1].isdigit()) → 이미 dR[i+1]는 먼저 접근됨
#     - AND는 “조건 분기” > not()은 “값을 만들기 위해 무조건 계산”
#     - if절 인덱스오류남..... 포기
#         - 인덱스 방식은(for) “항상 뒤를 미리 예측해야 해서 위험하고 지저분함”
#         - 포인터 방식은(while i 조건:) “현재 위치 기준으로 자연스럽게 이동해서 안전함”

# %% [markdown]
# 다른 사람 풀이

# %%
#조건에 따라 바로 연산, 리스트와 인덱스 활용.. 내가 짜고싶었던 코드의 더 깔끔한 버전
#if 대신 딕셔너리
#if not을 and랑 같이 쓰다 인덱스 오류났는데.. 코드 마지막에 n=i+1
def solution(dartResult):
    dart = {'S':1, 'D':2, 'T':3}
    scores = []
    n = 0

    for i, d in enumerate(dartResult):
        if d in dart:
            scores.append(int(dartResult[n:i]) ** dart[d])
        if d == "*":
            scores[-2:] = [x*2 for x in scores[-2:]]
        if d == "#":
            scores[-1] = (-1) * scores[-1]
        if not (d.isnumeric()):
            n = i + 1

    return sum(scores)

# %%
#정규식으로 문자열을 점수 단위(한 세트)로 자동 분리하는 코드
import re

def solution(dartResult):
    bonus = {'S' : 1, 'D' : 2, 'T' : 3}
    option = {'' : 1, '*' : 2, '#' : -1}
    p = re.compile('(\d+)([SDT])([*#]?)')
    dart = p.findall(dartResult)
    for i in range(len(dart)):
        if dart[i][2] == '*' and i > 0:
            dart[i-1] *= 2
        dart[i] = int(dart[i][0]) ** bonus[dart[i][1]] * option[dart[i][2]]

    answer = sum(dart)
    return answer

# %% [markdown]
# - re.compile: “이 패턴을 미리 만들어 놓겠다”
# - \d: 숫자, (0~9) +: 1개 이상/ S, D, T 중 하나/ * or # 또는 없음, ?: 0개 또는 1개
# - .findall(): 문자열을 위 패턴 기준으로 자동 분해해서 튜플 리스트로 반환

# %%
def solution(dartResult):
    point = []
    answer = []
    dartResult = dartResult.replace('10','k')
    point = ['10' if i == 'k' else i for i in dartResult]
    print(point)

    i = -1
    sdt = ['S', 'D', 'T']
    for j in point:
        if j in sdt:
            answer[i] = answer[i] ** (sdt.index(j) + 1)
        elif j == '*':
            answer[i] = answer[i] * 2
            if i != 0:
                answer[i - 1] = answer[i - 1] * 2
        elif j == '#':
            answer[i] = answer[i] * (-1)
        else:
            answer.append(int(j))
            i += 1
    return sum(answer)

# %%
#지피티
def solution(dartResult):
    score = []
    i = 0

    while i < len(dartResult):
        # 1) 숫자 처리 (10까지 고려)
        if dartResult[i:i+2] == "10":
            n = 10
            i += 2
        else:
            n = int(dartResult[i])
            i += 1

        # 2) S D T
        if dartResult[i] == "S":
            n **= 1
        elif dartResult[i] == "D":
            n **= 2
        else:
            n **= 3
        i += 1

        # 3) * #
        if i < len(dartResult) and dartResult[i] in "*#":
            if dartResult[i] == "*":
                n *= 2
                if score:
                    score[-1] *= 2
            else:
                n *= -1
            i += 1

        score.append(n)

    return sum(score)
